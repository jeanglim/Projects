# %% [markdown]
# # Training the DQN Model using CNN at 350,000 steps

# %%
import gymnasium as gym
from stable_baselines3 import DQN
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack

GAME_NAME = "ALE/Pacman-v5"

env_id = f"{GAME_NAME}"
env = make_atari_env(env_id, n_envs=1, seed=0)
env = VecFrameStack(env, n_stack=4)

model = DQN('CnnPolicy', env, verbose=1, tensorboard_log="./atari_dqn_tensorboard/")

TIMESTEPS = 350000
model.learn(total_timesteps=TIMESTEPS)

model_save_path = f"{GAME_NAME}_dqn_model"
model.save(model_save_path)

print("Model trained and saved successfully.")
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# ERROR! Session/line number was not unique in database. History logging moved to new session 747
# Logging to ./atari_dqn_tensorboard/DQN_23
# C:\Users\jrhaley\AppData\Local\anaconda3\Anaconda_Prompt\Lib\site-packages\stable_baselines3\common\buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 56.46GB > 32.06GB
#   warnings.warn(
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 438      |
# |    ep_rew_mean      | 18       |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 234      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 101      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 421      |
# |    ep_rew_mean      | 17.5     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 113      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 199      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0333   |
# |    n_updates        | 24       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 411      |
# |    ep_rew_mean      | 18       |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 86       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 294      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0576   |
# |    n_updates        | 48       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 428      |
# |    ep_rew_mean      | 19.2     |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 77       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 404      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0655   |
# |    n_updates        | 75       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 434      |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 72       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 513      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0437   |
# |    n_updates        | 103      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 445      |
# |    ep_rew_mean      | 23.2     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 71       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 628      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0727   |
# |    n_updates        | 131      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 443      |
# |    ep_rew_mean      | 23.3     |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 71       |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 734      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.106    |
# |    n_updates        | 158      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 472      |
# |    ep_rew_mean      | 24.9     |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 70       |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 898      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0401   |
# |    n_updates        | 199      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 478      |
# |    ep_rew_mean      | 25.2     |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 69       |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 1024     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0444   |
# |    n_updates        | 230      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 473      |
# |    ep_rew_mean      | 24.2     |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 68       |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 1125     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0515   |
# |    n_updates        | 256      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 470      |
# |    ep_rew_mean      | 23.5     |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 67       |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 1225     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0983   |
# |    n_updates        | 281      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 471      |
# |    ep_rew_mean      | 23.2     |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 67       |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 1340     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0643   |
# |    n_updates        | 309      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 464      |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 67       |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 1432     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0892   |
# |    n_updates        | 332      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 470      |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 67       |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 1562     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0843   |
# |    n_updates        | 365      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 473      |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 67       |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 1687     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0365   |
# |    n_updates        | 396      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 494      |
# |    ep_rew_mean      | 34.6     |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 68       |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 1880     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.05     |
# |    n_updates        | 444      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 486      |
# |    ep_rew_mean      | 33.2     |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 68       |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 1964     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0843   |
# |    n_updates        | 465      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 486      |
# |    ep_rew_mean      | 32.7     |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 68       |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 2081     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0717   |
# |    n_updates        | 495      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 479      |
# |    ep_rew_mean      | 31.5     |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 68       |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 2164     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.109    |
# |    n_updates        | 515      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 477      |
# |    ep_rew_mean      | 30.9     |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 68       |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 2264     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0914   |
# |    n_updates        | 540      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 474      |
# |    ep_rew_mean      | 30.3     |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 68       |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 2364     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0598   |
# |    n_updates        | 565      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 472      |
# |    ep_rew_mean      | 29.7     |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 67       |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 2461     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0513   |
# |    n_updates        | 590      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 467      |
# |    ep_rew_mean      | 29.1     |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 67       |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 2547     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.109    |
# |    n_updates        | 611      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 465      |
# |    ep_rew_mean      | 28.6     |
# |    exploration_rate | 0.928    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 66       |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 2643     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0302   |
# |    n_updates        | 635      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 460      |
# |    ep_rew_mean      | 27.8     |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 66       |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 2722     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0634   |
# |    n_updates        | 655      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 458      |
# |    ep_rew_mean      | 27.7     |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 66       |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 2823     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0392   |
# |    n_updates        | 680      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 462      |
# |    ep_rew_mean      | 27.6     |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 65       |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 2957     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0965   |
# |    n_updates        | 714      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 460      |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 65       |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 3056     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0769   |
# |    n_updates        | 738      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 456      |
# |    ep_rew_mean      | 26.7     |
# |    exploration_rate | 0.915    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 64       |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 3142     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0654   |
# |    n_updates        | 760      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 460      |
# |    ep_rew_mean      | 26.7     |
# |    exploration_rate | 0.911    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 64       |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 3276     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0434   |
# |    n_updates        | 793      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 457      |
# |    ep_rew_mean      | 26.5     |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 63       |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 3362     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0528   |
# |    n_updates        | 815      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 458      |
# |    ep_rew_mean      | 26.6     |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 62       |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 3475     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0792   |
# |    n_updates        | 843      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 456      |
# |    ep_rew_mean      | 26.3     |
# |    exploration_rate | 0.903    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 62       |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 3566     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0979   |
# |    n_updates        | 866      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 455      |
# |    ep_rew_mean      | 26       |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 62       |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 3669     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0713   |
# |    n_updates        | 892      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 454      |
# |    ep_rew_mean      | 25.7     |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 61       |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 3764     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0343   |
# |    n_updates        | 915      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 451      |
# |    ep_rew_mean      | 25.1     |
# |    exploration_rate | 0.896    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 61       |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 3847     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0334   |
# |    n_updates        | 936      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 451      |
# |    ep_rew_mean      | 25.1     |
# |    exploration_rate | 0.893    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 61       |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 3956     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.046    |
# |    n_updates        | 963      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 454      |
# |    ep_rew_mean      | 25.3     |
# |    exploration_rate | 0.889    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 60       |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 4083     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0742   |
# |    n_updates        | 995      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 453      |
# |    ep_rew_mean      | 25.1     |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 60       |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 4179     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0491   |
# |    n_updates        | 1019     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 452      |
# |    ep_rew_mean      | 24.9     |
# |    exploration_rate | 0.884    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 60       |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 4278     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0854   |
# |    n_updates        | 1044     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 451      |
# |    ep_rew_mean      | 24.8     |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 60       |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 4368     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0835   |
# |    n_updates        | 1066     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 448      |
# |    ep_rew_mean      | 24.4     |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 59       |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 4451     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0608   |
# |    n_updates        | 1087     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 449      |
# |    ep_rew_mean      | 24.4     |
# |    exploration_rate | 0.876    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 59       |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 4556     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0814   |
# |    n_updates        | 1113     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 448      |
# |    ep_rew_mean      | 24.3     |
# |    exploration_rate | 0.874    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 59       |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 4659     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0674   |
# |    n_updates        | 1139     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 452      |
# |    ep_rew_mean      | 25.2     |
# |    exploration_rate | 0.869    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 58       |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 4811     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0821   |
# |    n_updates        | 1177     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 451      |
# |    ep_rew_mean      | 25.1     |
# |    exploration_rate | 0.867    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 58       |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 4903     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.113    |
# |    n_updates        | 1200     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 449      |
# |    ep_rew_mean      | 25       |
# |    exploration_rate | 0.865    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 58       |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 4991     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0542   |
# |    n_updates        | 1222     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 448      |
# |    ep_rew_mean      | 24.8     |
# |    exploration_rate | 0.862    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 58       |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 5073     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0737   |
# |    n_updates        | 1243     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 447      |
# |    ep_rew_mean      | 24.6     |
# |    exploration_rate | 0.86     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 57       |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 5169     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0936   |
# |    n_updates        | 1267     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 449      |
# |    ep_rew_mean      | 24.8     |
# |    exploration_rate | 0.856    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 57       |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 5301     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0532   |
# |    n_updates        | 1300     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 450      |
# |    ep_rew_mean      | 24.7     |
# |    exploration_rate | 0.853    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 57       |
# |    time_elapsed     | 94       |
# |    total_timesteps  | 5424     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0545   |
# |    n_updates        | 1330     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 450      |
# |    ep_rew_mean      | 24.7     |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 56       |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 5521     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.057    |
# |    n_updates        | 1355     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 450      |
# |    ep_rew_mean      | 24.7     |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 56       |
# |    time_elapsed     | 99       |
# |    total_timesteps  | 5632     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0348   |
# |    n_updates        | 1382     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 449      |
# |    ep_rew_mean      | 24.5     |
# |    exploration_rate | 0.844    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 56       |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 5729     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0754   |
# |    n_updates        | 1407     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 447      |
# |    ep_rew_mean      | 24.2     |
# |    exploration_rate | 0.842    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 56       |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 5811     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0623   |
# |    n_updates        | 1427     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 447      |
# |    ep_rew_mean      | 24.3     |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 56       |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 5907     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0546   |
# |    n_updates        | 1451     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 450      |
# |    ep_rew_mean      | 24.5     |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 56       |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 6052     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0635   |
# |    n_updates        | 1487     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 449      |
# |    ep_rew_mean      | 24.4     |
# |    exploration_rate | 0.833    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 55       |
# |    time_elapsed     | 110      |
# |    total_timesteps  | 6148     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0304   |
# |    n_updates        | 1511     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 448      |
# |    ep_rew_mean      | 24.2     |
# |    exploration_rate | 0.831    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 55       |
# |    time_elapsed     | 111      |
# |    total_timesteps  | 6231     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0643   |
# |    n_updates        | 1532     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 447      |
# |    ep_rew_mean      | 24.1     |
# |    exploration_rate | 0.829    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 55       |
# |    time_elapsed     | 113      |
# |    total_timesteps  | 6315     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0615   |
# |    n_updates        | 1553     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 446      |
# |    ep_rew_mean      | 23.9     |
# |    exploration_rate | 0.826    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 55       |
# |    time_elapsed     | 116      |
# |    total_timesteps  | 6412     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.061    |
# |    n_updates        | 1577     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 446      |
# |    ep_rew_mean      | 23.8     |
# |    exploration_rate | 0.823    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 54       |
# |    time_elapsed     | 118      |
# |    total_timesteps  | 6516     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0538   |
# |    n_updates        | 1603     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 450      |
# |    ep_rew_mean      | 23.9     |
# |    exploration_rate | 0.819    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 54       |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 6683     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.071    |
# |    n_updates        | 1645     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 450      |
# |    ep_rew_mean      | 23.8     |
# |    exploration_rate | 0.816    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 54       |
# |    time_elapsed     | 124      |
# |    total_timesteps  | 6781     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0509   |
# |    n_updates        | 1670     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 451      |
# |    ep_rew_mean      | 23.8     |
# |    exploration_rate | 0.813    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 54       |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 6907     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0546   |
# |    n_updates        | 1701     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 451      |
# |    ep_rew_mean      | 23.8     |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 53       |
# |    time_elapsed     | 129      |
# |    total_timesteps  | 7007     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0411   |
# |    n_updates        | 1726     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 449      |
# |    ep_rew_mean      | 23.6     |
# |    exploration_rate | 0.808    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 53       |
# |    time_elapsed     | 131      |
# |    total_timesteps  | 7081     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0815   |
# |    n_updates        | 1745     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 448      |
# |    ep_rew_mean      | 23.6     |
# |    exploration_rate | 0.805    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 53       |
# |    time_elapsed     | 134      |
# |    total_timesteps  | 7176     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0465   |
# |    n_updates        | 1768     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 448      |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.802    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 53       |
# |    time_elapsed     | 136      |
# |    total_timesteps  | 7279     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0435   |
# |    n_updates        | 1794     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 448      |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.8      |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 53       |
# |    time_elapsed     | 138      |
# |    total_timesteps  | 7376     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0483   |
# |    n_updates        | 1818     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 450      |
# |    ep_rew_mean      | 23.6     |
# |    exploration_rate | 0.796    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 52       |
# |    time_elapsed     | 142      |
# |    total_timesteps  | 7518     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0528   |
# |    n_updates        | 1854     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 448      |
# |    ep_rew_mean      | 23.5     |
# |    exploration_rate | 0.794    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 52       |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 7600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0505   |
# |    n_updates        | 1874     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 447      |
# |    ep_rew_mean      | 23.2     |
# |    exploration_rate | 0.792    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 52       |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 7675     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0415   |
# |    n_updates        | 1893     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 446      |
# |    ep_rew_mean      | 23.1     |
# |    exploration_rate | 0.789    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 52       |
# |    time_elapsed     | 147      |
# |    total_timesteps  | 7768     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0348   |
# |    n_updates        | 1916     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 446      |
# |    ep_rew_mean      | 23.1     |
# |    exploration_rate | 0.786    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 52       |
# |    time_elapsed     | 150      |
# |    total_timesteps  | 7872     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.016    |
# |    n_updates        | 1942     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 445      |
# |    ep_rew_mean      | 23.1     |
# |    exploration_rate | 0.784    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 52       |
# |    time_elapsed     | 152      |
# |    total_timesteps  | 7955     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0592   |
# |    n_updates        | 1963     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 443      |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.782    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 52       |
# |    time_elapsed     | 154      |
# |    total_timesteps  | 8030     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0946   |
# |    n_updates        | 1982     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 445      |
# |    ep_rew_mean      | 23       |
# |    exploration_rate | 0.778    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 51       |
# |    time_elapsed     | 157      |
# |    total_timesteps  | 8164     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0797   |
# |    n_updates        | 2015     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 445      |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.776    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 51       |
# |    time_elapsed     | 160      |
# |    total_timesteps  | 8266     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0446   |
# |    n_updates        | 2041     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 445      |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.773    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 51       |
# |    time_elapsed     | 162      |
# |    total_timesteps  | 8367     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0496   |
# |    n_updates        | 2066     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 444      |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.77     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 51       |
# |    time_elapsed     | 165      |
# |    total_timesteps  | 8467     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0344   |
# |    n_updates        | 2091     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 444      |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.768    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 50       |
# |    time_elapsed     | 168      |
# |    total_timesteps  | 8562     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0343   |
# |    n_updates        | 2115     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 444      |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.765    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 50       |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 8668     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0477   |
# |    n_updates        | 2141     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 444      |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.762    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 50       |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 8759     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0509   |
# |    n_updates        | 2164     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 444      |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.759    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 50       |
# |    time_elapsed     | 176      |
# |    total_timesteps  | 8867     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0244   |
# |    n_updates        | 2191     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 443      |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.757    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 50       |
# |    time_elapsed     | 178      |
# |    total_timesteps  | 8966     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0469   |
# |    n_updates        | 2216     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 442      |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.754    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 50       |
# |    time_elapsed     | 180      |
# |    total_timesteps  | 9049     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0548   |
# |    n_updates        | 2237     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 443      |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.751    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 49       |
# |    time_elapsed     | 183      |
# |    total_timesteps  | 9172     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0579   |
# |    n_updates        | 2267     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 442      |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.749    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 49       |
# |    time_elapsed     | 185      |
# |    total_timesteps  | 9261     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0507   |
# |    n_updates        | 2290     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 443      |
# |    ep_rew_mean      | 22.5     |
# |    exploration_rate | 0.746    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 49       |
# |    time_elapsed     | 188      |
# |    total_timesteps  | 9373     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0477   |
# |    n_updates        | 2318     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 443      |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.743    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 49       |
# |    time_elapsed     | 190      |
# |    total_timesteps  | 9475     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# ...
# |    total_timesteps  | 342850   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.459    |
# |    n_updates        | 85687    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01e+03 |
# |    ep_rew_mean      | 180      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7376     |
# |    fps              | 16       |
# |    time_elapsed     | 21083    |
# |    total_timesteps  | 343055   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.626    |
# |    n_updates        | 85738    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01e+03 |
# |    ep_rew_mean      | 180      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7380     |
# |    fps              | 16       |
# |    time_elapsed     | 21093    |
# |    total_timesteps  | 343330   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.611    |
# |    n_updates        | 85807    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 176      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7384     |
# |    fps              | 16       |
# |    time_elapsed     | 21100    |
# |    total_timesteps  | 343522   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.559    |
# |    n_updates        | 85855    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 178      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7388     |
# |    fps              | 16       |
# |    time_elapsed     | 21108    |
# |    total_timesteps  | 343759   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.258    |
# |    n_updates        | 85914    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01e+03 |
# |    ep_rew_mean      | 178      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7392     |
# |    fps              | 16       |
# |    time_elapsed     | 21117    |
# |    total_timesteps  | 343991   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.263    |
# |    n_updates        | 85972    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01e+03 |
# |    ep_rew_mean      | 178      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7396     |
# |    fps              | 16       |
# |    time_elapsed     | 21126    |
# |    total_timesteps  | 344259   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.409    |
# |    n_updates        | 86039    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01e+03 |
# |    ep_rew_mean      | 179      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7400     |
# |    fps              | 16       |
# |    time_elapsed     | 21134    |
# |    total_timesteps  | 344473   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.109    |
# |    n_updates        | 86093    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 178      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7404     |
# |    fps              | 16       |
# |    time_elapsed     | 21142    |
# |    total_timesteps  | 344720   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.14     |
# |    n_updates        | 86154    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01e+03 |
# |    ep_rew_mean      | 180      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7408     |
# |    fps              | 16       |
# |    time_elapsed     | 21150    |
# |    total_timesteps  | 344941   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.264    |
# |    n_updates        | 86210    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 180      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7412     |
# |    fps              | 16       |
# |    time_elapsed     | 21160    |
# |    total_timesteps  | 345211   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.224    |
# |    n_updates        | 86277    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01e+03 |
# |    ep_rew_mean      | 180      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7416     |
# |    fps              | 16       |
# |    time_elapsed     | 21166    |
# |    total_timesteps  | 345370   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.38     |
# |    n_updates        | 86317    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01e+03 |
# |    ep_rew_mean      | 180      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7420     |
# |    fps              | 16       |
# |    time_elapsed     | 21177    |
# |    total_timesteps  | 345663   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.398    |
# |    n_updates        | 86390    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 180      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7424     |
# |    fps              | 16       |
# |    time_elapsed     | 21184    |
# |    total_timesteps  | 345874   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.3      |
# |    n_updates        | 86443    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 999      |
# |    ep_rew_mean      | 178      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7428     |
# |    fps              | 16       |
# |    time_elapsed     | 21188    |
# |    total_timesteps  | 346012   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.505    |
# |    n_updates        | 86477    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 996      |
# |    ep_rew_mean      | 178      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7432     |
# |    fps              | 16       |
# |    time_elapsed     | 21199    |
# |    total_timesteps  | 346300   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.547    |
# |    n_updates        | 86549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 996      |
# |    ep_rew_mean      | 177      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7436     |
# |    fps              | 16       |
# |    time_elapsed     | 21208    |
# |    total_timesteps  | 346590   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.26     |
# |    n_updates        | 86622    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 997      |
# |    ep_rew_mean      | 177      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7440     |
# |    fps              | 16       |
# |    time_elapsed     | 21212    |
# |    total_timesteps  | 346720   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.328    |
# |    n_updates        | 86654    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 996      |
# |    ep_rew_mean      | 177      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7444     |
# |    fps              | 16       |
# |    time_elapsed     | 21220    |
# |    total_timesteps  | 346958   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.397    |
# |    n_updates        | 86714    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 998      |
# |    ep_rew_mean      | 177      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7448     |
# |    fps              | 16       |
# |    time_elapsed     | 21226    |
# |    total_timesteps  | 347120   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.544    |
# |    n_updates        | 86754    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 998      |
# |    ep_rew_mean      | 177      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7452     |
# |    fps              | 16       |
# |    time_elapsed     | 21234    |
# |    total_timesteps  | 347357   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.431    |
# |    n_updates        | 86814    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 995      |
# |    ep_rew_mean      | 177      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7456     |
# |    fps              | 16       |
# |    time_elapsed     | 21242    |
# |    total_timesteps  | 347559   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.856    |
# |    n_updates        | 86864    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 994      |
# |    ep_rew_mean      | 177      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7460     |
# |    fps              | 16       |
# |    time_elapsed     | 21250    |
# |    total_timesteps  | 347776   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.332    |
# |    n_updates        | 86918    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 996      |
# |    ep_rew_mean      | 178      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7464     |
# |    fps              | 16       |
# |    time_elapsed     | 21261    |
# |    total_timesteps  | 348106   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.452    |
# |    n_updates        | 87001    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 997      |
# |    ep_rew_mean      | 178      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7468     |
# |    fps              | 16       |
# |    time_elapsed     | 21271    |
# |    total_timesteps  | 348384   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.356    |
# |    n_updates        | 87070    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 995      |
# |    ep_rew_mean      | 177      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7472     |
# |    fps              | 16       |
# |    time_elapsed     | 21278    |
# |    total_timesteps  | 348604   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.324    |
# |    n_updates        | 87125    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 994      |
# |    ep_rew_mean      | 178      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7476     |
# |    fps              | 16       |
# |    time_elapsed     | 21287    |
# |    total_timesteps  | 348876   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.453    |
# |    n_updates        | 87193    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 996      |
# |    ep_rew_mean      | 177      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7480     |
# |    fps              | 16       |
# |    time_elapsed     | 21297    |
# |    total_timesteps  | 349175   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.229    |
# |    n_updates        | 87268    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 176      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7484     |
# |    fps              | 16       |
# |    time_elapsed     | 21305    |
# |    total_timesteps  | 349374   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.536    |
# |    n_updates        | 87318    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 999      |
# |    ep_rew_mean      | 177      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7488     |
# |    fps              | 16       |
# |    time_elapsed     | 21314    |
# |    total_timesteps  | 349612   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.314    |
# |    n_updates        | 87377    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 177      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7492     |
# |    fps              | 16       |
# |    time_elapsed     | 21323    |
# |    total_timesteps  | 349879   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.314    |
# |    n_updates        | 87444    |
# ----------------------------------
# Model trained and saved successfully.

# %% [markdown]
# # Evaluating the DQN Model
#     1. Load in the model
#     2. Evaluate the model over multiple episodes
#     3. See how many rewards it collected

# %%
import gymnasium as gym
from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy
import numpy as np
from stable_baselines3 import DQN
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack
import matplotlib.pyplot as plt

GAME_NAME = "ALE/Pacman-v5"

env_id = f"{GAME_NAME}"
env = make_atari_env(env_id, n_envs=1, seed=0)
env = VecFrameStack(env, n_stack=4)

model = DQN.load(f"{GAME_NAME}_dqn_model.zip", env=env)

mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
print(f"Mean reward: {mean_reward} +/- {std_reward}")

def evaluate_game(model, env):
    obs = env.reset()
    done = False
    total_reward = 0
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(action)
        total_reward += reward
    return total_reward

num_episodes = 50
total_rewards = []

for _ in range(num_episodes):
    episode_reward = evaluate_game(model, env)
    total_rewards.append(episode_reward)

print(f"Average Reward per Game: {np.mean(total_rewards)}")

import numpy as np  

episode_list = np.array([i + 1 for i in range(num_episodes)], dtype='int32')
score = np.array([reward.item() for reward in total_rewards], dtype='int32')

summary = np.column_stack((episode_list,score))

print('evealuation done')
print(summary)
# Out:
# Wrapping the env in a VecTransposeImage.
# C:\Users\jrhaley\AppData\Local\anaconda3\Anaconda_Prompt\Lib\site-packages\stable_baselines3\common\buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 56.46GB > 51.35GB
#   warnings.warn(
# Mean reward: 177.4 +/- 76.17899973089696
# Average Reward per Game: 20.260000228881836
# evealuation done
# [[ 1 59]
#  [ 2  7]
#  [ 3 15]
#  [ 4  0]
#  [ 5 11]
#  [ 6 38]
#  [ 7 18]
#  [ 8  2]
#  [ 9 51]
#  [10 27]
#  [11  0]
#  [12  3]
#  [13 37]
#  [14 35]
#  [15  2]
#  [16  3]
#  [17 59]
#  [18 14]
#  [19 17]
#  [20  0]
#  [21 28]
#  [22 56]
#  [23  0]
#  [24  1]
#  [25 30]
#  [26 37]
#  [27  9]
#  [28  0]
#  [29 53]
#  [30 22]
#  [31  7]
#  [32  1]
#  [33 33]
#  [34 44]
#  [35 11]
#  [36  0]
#  [37 28]
#  [38 27]
#  [39  1]
#  [40  0]
#  [41 56]
#  [42 12]
#  [43 16]
#  [44  0]
#  [45 49]
#  [46 12]
#  [47 10]
#  [48  0]
#  [49 37]
#  [50 35]]
